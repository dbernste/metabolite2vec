# %% [markdown]
# # metabolite2vec:
# In this notebook, the word2vec algorithm and skipgram model for embedding words in a feature space that represents their context was adapted to embed metabolites. The code here was initially adapted from the [TensorFlow word2vec tutorial](https://www.tensorflow.org/tutorials/representation/word2vec). [Arxiv paper](https://arxiv.org/pdf/1310.4546.pdf).

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### Step 1a: Load the Data (ModelSEED)
# ModelSEED contains a large database of metabolites and metabolic reactions. This databases consists of 27,694 metabolites and 34,711 reactions, which can be downloaded from the ModelSEED github. Metabolite and reaction details can be viewed on the model seed website (modelseed.org).

# %%
# Load Data (ModelSEED database reactions, modelseed.org)
# The modelseed reactions metadata has a column corresponding to the metabolites used by a reaciton, 
# this column will be the entirety of our data.

import csv
file_name = './reactions.tsv'
data_c = []
with open(file_name) as tsvfile:
    reader = csv.DictReader(tsvfile,dialect='excel-tab')
    for row in reader:
        tmp = row['compound_ids']
        data_c.append(tmp.split(';'))
# remove reactions with only 1 metabolite
indexes = []
for i in range(len(data_c)):
    if len(data_c[i]) <= 1:
        indexes.append(i)
for index in sorted(indexes, reverse=True):
    del data_c[index]
    
# Load metabolite names
# Metabolites names will be used for a dictionary that converts metabolite ids to names for data visualization
file_name = './compounds.tsv'
name_dictionary = dict()
with open(file_name) as tsvfile:
    reader = csv.DictReader(tsvfile,dialect='excel-tab')
    for row in reader:
        tmp1 = row['id']
        tmp2 = row['abbreviation']
        name_dictionary[tmp1]=tmp2
        
# Deifne other dictionarys for data manipulation
# count, dictionary, reverse_dictionary, data, sort_dicitonary

# count: the number of times each metabolite appears in any reaction
from collections import Counter
from itertools import chain
count = Counter(chain.from_iterable(data_c))

# dictionary: to convert metabolite ids to a unique index
dictionary = dict()
for word in count:
    dictionary[word] = len(dictionary)
# reverse_dicitonary: to convert metabolite index back to ids
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))

# data: convert metabolite id data to index data
data = []
for rxn in data_c:
    data.append([dictionary[cmp] for cmp in rxn])

# vocabulary size: the total number of unique metabolites
vocabulary_size = len(count)

# sort dictionary: dictionary to get metabolite index sorted by count
import operator
sorted_count = sorted(count.items(), key=operator.itemgetter(1))
sorted_count.reverse()
sort_dictionary = dict()
for x in sorted_count:
    tmp = x[0]
    sort_dictionary[len(sort_dictionary)] = dictionary[tmp]
    
# Plot data
# plot the frequency of metabolite counts in reactions to get an idea of what the data looks like
import matplotlib.pyplot as plt
import numpy as np

sorted_count_a = np.array(sorted_count)
plt.plot(sorted_count_a[:,1].astype(float))
plt.show()

# %% [markdown]
# ### Step 1b: Load the Data (KEGG)
# KEGG is an alternative database of reactions and metabolties. Using this load code, sentences will be KEGG reactions and words will be KEGG metabolites.
#
# https://www.genome.jp/kegg/

# %%
# Load KEGG Reactions JSON file
import json
with open('./KEGG_R_db_27jun18.json') as json_file:
    js = json.load(json_file)
import re
data_c = []
for i in range(len(js)):
    # Exctract reaction metabolites from json data
    tmp = js[i]['EQUATION'][0]
    index = [m.start() for m in re.finditer('\D\d\d\d\d\d', tmp)]
    lst = []
    for j in range(len(index)):
        lst.append(tmp[index[j]:index[j]+6])
    data_c.append(lst)
    
# remove reactions with only 1 metabolite
indexes = []
for i in range(len(data_c)):
    if len(data_c[i]) <= 1:
        indexes.append(i)
for index in sorted(indexes, reverse=True):
    del data_c[index]

# Load metabolite names
# Metabolites names will be used for a dictionary that converts metabolite ids to names for data visualization
with open('./KEGG_C_db_27jun18.json') as json_file:
    js = json.load(json_file)
name_dictionary = dict()
for key in js.keys():
    tmp1 = key
    tmp2 = js[key]['NAME']
    name_dictionary[tmp1]=tmp2

# Deifne other dictionarys for data manipulation
# count, dictionary, reverse_dictionary, data, sort_dicitonary

# count: the number of times each metabolite appears in any reaction
from collections import Counter
from itertools import chain
count = Counter(chain.from_iterable(data_c))

# dictionary: to convert metabolite ids to a unique index
dictionary = dict()
for word in count:
    dictionary[word] = len(dictionary)
# reverse_dicitonary: to convert metabolite index back to ids
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))

# data: convert metabolite id data to index data
data = []
for rxn in data_c:
    data.append([dictionary[cmp] for cmp in rxn])

# vocabulary size: the total number of unique metabolites
vocabulary_size = len(count)

# sort dictionary: dictionary to get metabolite index sorted by count
import operator
sorted_count = sorted(count.items(), key=operator.itemgetter(1))
sorted_count.reverse()
sort_dictionary = dict()
for x in sorted_count:
    tmp = x[0]
    sort_dictionary[len(sort_dictionary)] = dictionary[tmp]
    
# Plot data
# plot the frequency of metabolite counts in reactions to get an idea of what the data looks like
import matplotlib.pyplot as plt
import numpy as np

sorted_count_a = np.array(sorted_count)
plt.plot(sorted_count_a[:,1].astype(float))
plt.show()

# %% [markdown]
# ### Step 1b_2: Load the Data (KEGG)
# This will load the same data as step 1b but will only consider metabolites to be in the same context if they are on the same side of a reaction

# %%
# Load KEGG Reactions JSON file
import json
with open('./KEGG_R_db_27jun18.json') as json_file:
    js1 = json.load(json_file)
import re
data_c = []
for i in range(len(js1)):
    # Exctract reaction metabolites from json data
    tmp = js1[i]['EQUATION'][0]
    tmpS = tmp.split('=')
    for s in range(len(tmpS)):
        tmp = tmpS[s]
        index = [m.start() for m in re.finditer('\D\d\d\d\d\d', tmp)]
        lst = []
        for j in range(len(index)):
            lst.append(tmp[index[j]:index[j]+6])
        data_c.append(lst)
    
# remove reactions with only 1 metabolite
indexes = []
for i in range(len(data_c)):
    if len(data_c[i]) <= 1:
        indexes.append(i)
for index in sorted(indexes, reverse=True):
    del data_c[index]

# Load metabolite names
# Metabolites names will be used for a dictionary that converts metabolite ids to names for data visualization
with open('./KEGG_C_db_27jun18.json') as json_file:
    js = json.load(json_file)
name_dictionary = dict()
for key in js.keys():
    tmp1 = key
    tmp2 = js[key]['NAME']
    name_dictionary[tmp1]=tmp2

# Deifne other dictionarys for data manipulation
# count, dictionary, reverse_dictionary, data, sort_dicitonary

# count: the number of times each metabolite appears in any reaction
from collections import Counter
from itertools import chain
count = Counter(chain.from_iterable(data_c))

# dictionary: to convert metabolite ids to a unique index
dictionary = dict()
for word in count:
    dictionary[word] = len(dictionary)
# reverse_dicitonary: to convert metabolite index back to ids
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))

# data: convert metabolite id data to index data
data = []
for rxn in data_c:
    data.append([dictionary[cmp] for cmp in rxn])

# vocabulary size: the total number of unique metabolites
vocabulary_size = len(count)

# sort dictionary: dictionary to get metabolite index sorted by count
import operator
sorted_count = sorted(count.items(), key=operator.itemgetter(1))
sorted_count.reverse()
sort_dictionary = dict()
for x in sorted_count:
    tmp = x[0]
    sort_dictionary[len(sort_dictionary)] = dictionary[tmp]
    
# Plot data
# plot the frequency of metabolite counts in reactions to get an idea of what the data looks like
import matplotlib.pyplot as plt
import numpy as np

sorted_count_a = np.array(sorted_count)
plt.plot(sorted_count_a[:,1].astype(float))
plt.show()

# %% [markdown]
# ### Step 1c: Load the Data (KEGG reaction classes)
# KEGG contains additional metadata related to reactions. One form of metadata stored in KEGG are reaciton classes and reaction pairs. Reaction classes and pairs represent chemical structure transformation patterns, and are a predifined way of annotating "metabolite phrases".
#
# for additional information on KEGG reaction classes:
# https://www.genome.jp/kegg/reaction/

# %%
# Load KEGG Reactions JSON file
import json
with open('./KEGG_R_db_27jun18.json') as json_file:
    js = json.load(json_file)
import re
data_c = []
for i in range(len(js)):
    d1 = js[i]
    if 'RCLASS' in d1.keys():
        # Exctract reaction classes from json data
        k1 = d1['RCLASS']
        lst = []
        for k in range(len(k1)):
            tmp = k1[k]
            # exctract compound pairs
            index = [m.start() for m in re.finditer('\D\d\d\d\d\d_\D\d\d\d\d\d', tmp)]
            for j in range(len(index)):
                lst.append(tmp[index[j]:index[j]+13])
        data_c.append(lst)
        
# remove reactions with only 1 metabolite pair
indexes = []
for i in range(len(data_c)):
    if len(data_c[i]) <= 1:
        indexes.append(i)
for index in sorted(indexes, reverse=True):
    del data_c[index]

# Load metabolite names
# Metabolites names will be used for a dictionary that converts metabolite ids to names for data visualization
with open('./KEGG_C_db_27jun18.json') as json_file:
    js = json.load(json_file)
name_dictionary = dict()
for key in js.keys():
    tmp1 = key
    tmp2 = js[key]['NAME']
    name_dictionary[tmp1]=tmp2

# Deifne other dictionarys for data manipulation
# count, dictionary, reverse_dictionary, data, sort_dicitonary

# count: the number of times each metabolite appears in any reaction
from collections import Counter
from itertools import chain
count = Counter(chain.from_iterable(data_c))

# dictionary: to convert metabolite ids to a unique index
dictionary = dict()
for word in count:
    dictionary[word] = len(dictionary)
# reverse_dicitonary: to convert metabolite index back to ids
reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))

# data: convert metabolite id data to index data
data = []
for rxn in data_c:
    data.append([dictionary[cmp] for cmp in rxn])

# vocabulary size: the total number of unique metabolites
vocabulary_size = len(count)

# sort dictionary: dictionary to get metabolite index sorted by count
import operator
sorted_count = sorted(count.items(), key=operator.itemgetter(1))
sorted_count.reverse()
sort_dictionary = dict()
for x in sorted_count:
    tmp = x[0]
    sort_dictionary[len(sort_dictionary)] = dictionary[tmp]
    
# Plot data
# plot the frequency of metabolite counts in reactions to get an idea of what the data looks like
import matplotlib.pyplot as plt
import numpy as np

sorted_count_a = np.array(sorted_count)
plt.plot(sorted_count_a[:,1].astype(float))
plt.show()

# %%
vocabulary_size
# Out:
# 6331

# %% [markdown]
# ### Step 2: Define how to Sample the Data
# The data is sampled by defining metabolites as words and metabolites that are products or reactants of the same reaction as context metabolites. To generate a single sample for a minibatch first a reaction is chosen at random, then 1 center and 1 context metabolite from that reaction are chosen at random as the input and label of the sampled data point. The model thus adjusts metabolite embeddings such that metabolites dot products predict metabolites that appear in the same context in metabolic reactions.

# %%
# Define function for generating a training batch
# Context is defined as all of the metabolites in a given reaction
# A batch is sampled by first randomly choosing a reaction and then randomly choosing 1 center and 1 neighbor metabolite
from random import randint
import numpy as np

def generate_batch(batch_size):
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    for i in range(batch_size):
        #choose random reaction
        tmp = data[randint(0,len(data)-1)]
        #choose random metabolite
        batch[i] = tmp[randint(0,len(tmp)-1)]
        labels[i] = tmp[randint(0,len(tmp)-1)]
    
    return batch, labels

# %%
# visualize a batch
batch_size = 10
batch, labels = generate_batch(batch_size)
for i in range(batch_size):
    if reverse_dictionary[batch[i]] in name_dictionary.keys():
        print(batch[i], name_dictionary[reverse_dictionary[batch[i]]], '->', labels[i, 0],
            name_dictionary[reverse_dictionary[labels[i, 0]]])
    else:
        print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
            reverse_dictionary[labels[i, 0]])
# Out:
# 77 ['D-Mannitol 1-phosphate'] -> 27 ['H2O;', 'Water']
# 7075 ['2-Hydroxy-6-oxo-6-(2-hydroxyphenyl)-hexa-2,4-dienoate'] -> 7075 ['2-Hydroxy-6-oxo-6-(2-hydroxyphenyl)-hexa-2,4-dienoate']
# 1 ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+'] -> 1 ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']
# 4126 ['Sedoheptulose 7-phosphate;', 'D-Sedoheptulose 7-phosphate;', 'D-altro-Heptulose 7-phosphate;', 'altro-Heptulose 7-phosphate'] -> 4126 ['Sedoheptulose 7-phosphate;', 'D-Sedoheptulose 7-phosphate;', 'D-altro-Heptulose 7-phosphate;', 'altro-Heptulose 7-phosphate']
# 1 ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+'] -> 635 ['O-Phospho-4-hydroxy-L-threonine;', '4-(Phosphonooxy)-threonine;', '4-(Phosphonooxy)-L-threonine;', '4-Phosphooxy-L-threonine']
# 167 ['CO2;', 'Carbon dioxide'] -> 167 ['CO2;', 'Carbon dioxide']
# 36 ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+'] -> 27 ['H2O;', 'Water']
# 401 ['17alpha-Hydroxyprogesterone;', '17alpha-Hydroxy-4-pregnene-3,20-dione;', 'Pregn-4-ene-3,20-dione-17-ol;', '17alpha-Hydroxy-progesterone'] -> 4 ['H+;', 'Hydron']
# 1086 ['S-Adenosyl-L-methionine;', 'S-Adenosylmethionine;', 'AdoMet;', 'SAM'] -> 1086 ['S-Adenosyl-L-methionine;', 'S-Adenosylmethionine;', 'AdoMet;', 'SAM']
# 1056 ['UTP;', "Uridine 5'-triphosphate;", 'Uridine triphosphate'] -> 5950 ['N-Acetyl-alpha-D-galactosamine 1-phosphate']

# %% [markdown]
# ### Step 3: Skip-gram Model
# A skip-gram model with noise contrastive estimation (NCE) loss was used for our method. For a quick introduction to the skip-gram model and how it translates over to a neural network see (http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/).

# %%
# Build and train a skip-gram model.

import tensorflow as tf
import math

# Hyperparameters:
batch_size = 64 # Size of mini-batch
embedding_size = 128  # Dimension of the embedding vector.
num_sampled = 64  # Number of negative examples to sample.
lr = 1 # Learning rate for Stochastic Gradient Descent

# Validation set: A set of metabolites to monitor the progress of the algorithm
# The metabolites chosen here do not impact the calculations
valid_size = 10  # number of validation examples to show
valid_examples_1 = range(valid_size)
valid_examples = [sort_dictionary[ex] for ex in valid_examples_1] #chooes the metabolites with the highest counts

graph = tf.Graph()

with graph.as_default():

    # Input data.
    with tf.name_scope('inputs'):
        train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        with tf.name_scope('embeddings'):
            embeddings = tf.Variable(
                tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
            embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
        nce_weights = tf.Variable(
            tf.truncated_normal(
                [vocabulary_size, embedding_size],
                stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
        loss = tf.reduce_mean(
            tf.nn.nce_loss(
                weights=nce_weights,
                biases=nce_biases,
                labels=train_labels,
                inputs=embed,
                num_sampled=num_sampled,
                num_classes=vocabulary_size))

    # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)
    
    # Construct the SGD optimizer
    with tf.name_scope('optimizer'):
        optimizer = tf.train.GradientDescentOptimizer(lr).minimize(loss)
    
    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()

# %%
# Begin training.

num_steps = 100001

with tf.Session(graph=graph) as session:

    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # Define metadata variable.
        run_metadata = tf.RunMetadata()

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
        # Feed metadata variable to session for visualizing the graph in TensorBoard.
        _, summary, loss_val = session.run(
            [optimizer, merged, loss],
            feed_dict=feed_dict,
            run_metadata=run_metadata)
        average_loss += loss_val
    

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 20000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 3  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                if valid_word in name_dictionary.keys():
                    log_str = 'Nearest to %s:' % name_dictionary[valid_word]
                else:
                    log_str = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    if reverse_dictionary[nearest[k]] in name_dictionary.keys():
                        close_word = name_dictionary[reverse_dictionary[nearest[k]]]
                    else:
                        close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  195.58657836914062
# Nearest to ['H2O;', 'Water']: ['Tryprostatin A'], ['Protein L-citrulline'], ['Peptide'],
# Nearest to ['H+;', 'Hydron']: ['Cycloserine;', 'D-Cycloserine'], ['(-)-Camphor'], ['Estrone;', '3-Hydroxy-1,3,5(10)-estratrien-17-one'],
# Nearest to ['Oxygen;', 'O2']: ['Pentanoate;', 'Valerate;', 'Pentanoic acid;', 'Valeric acid;', 'Valerianic acid;', 'n-Pentanoate;', 'n-Valeric acid'], ['S-Ribosyl-L-homocysteine;', 'S-D-Ribosyl-L-homocysteine;', 'Ribose-5-S-homocysteine;', 'S-Ribosylhomocysteine;', 'S-(5-Deoxy-D-ribos-5-yl)-L-homocysteine'], ['Momilactone A'],
# Nearest to ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+']: ['Fusicocca-2,10(14)-diene'], ['3-Hydroxy-5-phosphooxypentane-2,4-dione;', '3-Hydroxy-5-phosphonooxypentane-2,4-dione;', '3-Hydroxy-2,4-pentadione-5-phosphate;', 'P-HPD'], ['(4R)-4-Hydroxy-2-oxoglutarate;', '(R)-2-Hydroxy-4-oxopentanedioate;', 'D-4-Hydroxy-2-oxoglutarate'],
# Nearest to ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']: ['2-Naphthalenesulfonic acid;', 'Naphthalene-2-sulfonate'], ['Sorbitol 6-phosphate;', 'D-Sorbitol 6-phosphate;', 'D-Glucitol 6-phosphate'], ['[Protein]-(S)-2-amino-6-oxohexanoate'],
# Nearest to ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']: ['LysW-gamma-L-alpha-aminoadipate 6-semialdehyde'], ["3'-Hydroxy-N-methyl-(S)-coclaurine;", "(S)-3'-Hydroxy-N-methylcoclaurine"], ['beta-D-Glucosyl-1,4-N-acetyl-D-glucosaminyldiphosphoundecaprenol'],
# Nearest to ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']: ['D-glycero-beta-D-manno-Heptose 1,7-bisphosphate'], ['N5-Acyl-L-ornithine'], ['Sulfur donor;', 'S-donor'],
# Nearest to ['CO2;', 'Carbon dioxide']: G13087, ['1,5-Anhydro-D-mannitol'], ['1-(5-Phosphoribosyl)imidazole-4-acetate'],
# Nearest to ['ATP;', "Adenosine 5'-triphosphate"]: ['S-Methyl-5-thio-D-ribose 1-phosphate;', 'S-Methyl-5-thio-alpha-D-ribose 1-phosphate;', 'S-Methyl-5-thio-5-deoxy-D-ribose 1-phosphate'], ['[Dihydrolipoyllysine-residue succinyltransferase] S-succinyldihydrolipoyllysine;', 'S-Succinyldihydrolipoamide-E;', 'Enzyme N6-(S-succinyldihydrolipoyl)lysine'], ['11a-Hydroxyoxytetracycline'],
# Nearest to ['Diphosphate;', 'Diphosphoric acid;', 'Pyrophosphate;', 'Pyrophosphoric acid;', 'PPi']: ['Norsolorinic acid anthrone;', 'Noranthrone;', '2-Hexanoyl-1,3,6,8-tetrahydroxyanthracen-9(10H)-one'], ['Cinnamoyl-CoA;', 'S-(Cinnamoyl) coenzyme A'], ['Long-chain acyl-CoA'],
# Average loss at step  2000 :  33.6758807926178
# Average loss at step  4000 :  3.87590105175972
# Average loss at step  6000 :  2.5688923881053927
# Average loss at step  8000 :  2.2650047599077223
# Average loss at step  10000 :  2.0983616359233856
# Average loss at step  12000 :  1.9745542364120483
# Average loss at step  14000 :  1.9185792255997658
# Average loss at step  16000 :  1.844198053240776
# Average loss at step  18000 :  1.794914834022522
# Average loss at step  20000 :  1.7453725043833255
# Nearest to ['H2O;', 'Water']: ['7,9,12-Decaketide intermediate 6'], ['Pterostilbene'], ['Octadecanoyl-[acyl-carrier protein];', 'Stearoyl-[acyl-carrier protein]'],
# Nearest to ['H+;', 'Hydron']: ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate'], ['3-Oxo-5beta-cholanate;', '3-Oxo-5beta-cholan-24-oate'],
# Nearest to ['Oxygen;', 'O2']: ['[Reduced NADPH---hemoprotein reductase];', 'Reduced flavoprotein'], ['I-Urobilinogen;', 'Mesobilirubinogen;', 'Urobilinogen'], ['5-Acetamidopentanoate'],
# Nearest to ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+']: ['trans-1,2-Dichloroethene;', 'trans-Acetylene dichloride'], ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+'], ['Fusicocca-2,10(14)-diene'],
# Nearest to ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']: ['H+;', 'Hydron'], ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['2-Naphthalenesulfonic acid;', 'Naphthalene-2-sulfonate'],
# Nearest to ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']: ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+'], ['Quercitrin;', 'Quercetin 3-L-rhamnoside;', 'Quercetin 3-O-alpha-L-rhamnopyranoside'], ['Deoxycholic acid;', 'Deoxycholate;', '3alpha,12alpha-Dihydroxy-5beta-cholanate;', '3alpha,12alpha-Dihydroxy-5beta-cholanic acid'],
# Nearest to ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']: ['H+;', 'Hydron'], ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate'], ['Phenanthrene-3,4-diol;', '3,4-Dihydroxyphenanthrene'],
# Nearest to ['CO2;', 'Carbon dioxide']: ['Succinate;', 'Succinic acid;', 'Butanedionic acid;', 'Ethylenesuccinic acid'], ['24-Methylenecholesterol'], ['Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-(L-alanyl-L-alanyl)-D-alanyl-D-alanine'],
# Nearest to ['ATP;', "Adenosine 5'-triphosphate"]: ['Azomycin;', '2-Nitroimidazole'], ['S-Methyl-5-thio-D-ribose 1-phosphate;', 'S-Methyl-5-thio-alpha-D-ribose 1-phosphate;', 'S-Methyl-5-thio-5-deoxy-D-ribose 1-phosphate'], ['Spirodilactone'],
# Nearest to ['Diphosphate;', 'Diphosphoric acid;', 'Pyrophosphate;', 'Pyrophosphoric acid;', 'PPi']: ['AMP;', "Adenosine 5'-monophosphate;", 'Adenylic acid;', 'Adenylate;', "5'-AMP;", "5'-Adenylic acid;", "5'-Adenosine monophosphate;", "Adenosine 5'-phosphate"], ['3-Chloro-L-alanine'], G13081,
# Average loss at step  22000 :  1.727987343788147
# Average loss at step  24000 :  1.6988148832321166
# Average loss at step  26000 :  1.6550788665115834
# Average loss at step  28000 :  1.6364785893857479
# Average loss at step  30000 :  1.630560335934162
# Average loss at step  32000 :  1.5983290323615074
# Average loss at step  34000 :  1.5714196001291274
# Average loss at step  36000 :  1.5535571702718736
# Average loss at step  38000 :  1.540025872349739
# Average loss at step  40000 :  1.5374131659567356
# Nearest to ['H2O;', 'Water']: ['7,9,12-Decaketide intermediate 6'], ['ADP-mannose;', 'APD-D-mannose'], ['Prostaglandin H2;', '(5Z,13E)-(15S)-9alpha,11alpha-Epidioxy-15-hydroxyprosta-5,13-dienoate;', '(5Z,13E,15S)-9alpha,11alpha-Epidioxy-15-hydroxyprosta-5,13-dienoate;', 'PGH2;', '(5Z,9alpha,11alpha,13E,15S)-9,11-Epidioxy-15-hydroxy-prosta-5,13-dienoate'],
# Nearest to ['H+;', 'Hydron']: ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate'], ['Chlorobenzene;', 'Monochlorobenzene;', 'Benzene chloride;', 'Phenyl chloride'],
# Nearest to ['Oxygen;', 'O2']: ['[Reduced NADPH---hemoprotein reductase];', 'Reduced flavoprotein'], ['I-Urobilinogen;', 'Mesobilirubinogen;', 'Urobilinogen'], ['6-Deoxoteasterone'],
# Nearest to ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+']: ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+'], ['Fusicocca-2,10(14)-diene'], ['trans-1,2-Dichloroethene;', 'trans-Acetylene dichloride'],
# Nearest to ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']: ['H+;', 'Hydron'], ['2-Naphthalenesulfonic acid;', 'Naphthalene-2-sulfonate'], ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'],
# Nearest to ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']: ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+'], ['Quercitrin;', 'Quercetin 3-L-rhamnoside;', 'Quercetin 3-O-alpha-L-rhamnopyranoside'], ['6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate'],
# Nearest to ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']: ['H+;', 'Hydron'], ['Phenanthrene-3,4-diol;', '3,4-Dihydroxyphenanthrene'], ["3''-Oxogentamicin A2"],
# Nearest to ['CO2;', 'Carbon dioxide']: ['Succinate;', 'Succinic acid;', 'Butanedionic acid;', 'Ethylenesuccinic acid'], ['Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-(L-alanyl-L-alanyl)-D-alanyl-D-alanine'], ['[Dihydrolipoyllysine-residue acetyltransferase] S-acetyldihydrolipoyllysine;', 'S-Acetyldihydrolipoamide-E;', 'Enzyme N6-(S-acetyldihydrolipoyl)lysine'],
# Nearest to ['ATP;', "Adenosine 5'-triphosphate"]: ['Azomycin;', '2-Nitroimidazole'], ['S-Methyl-5-thio-D-ribose 1-phosphate;', 'S-Methyl-5-thio-alpha-D-ribose 1-phosphate;', 'S-Methyl-5-thio-5-deoxy-D-ribose 1-phosphate'], ['(-)-Limonene;', '(-)-(S)-Limonene;', '(-)-(4S)-Limonene'],
# Nearest to ['Diphosphate;', 'Diphosphoric acid;', 'Pyrophosphate;', 'Pyrophosphoric acid;', 'PPi']: ['AMP;', "Adenosine 5'-monophosphate;", 'Adenylic acid;', 'Adenylate;', "5'-AMP;", "5'-Adenylic acid;", "5'-Adenosine monophosphate;", "Adenosine 5'-phosphate"], ['3-Chloro-L-alanine'], ['2-Hydroxy-3-methylbenzalpyruvate'],
# Average loss at step  42000 :  1.509088120162487
# Average loss at step  44000 :  1.486328831911087
# Average loss at step  46000 :  1.488317447423935
# Average loss at step  48000 :  1.4898685095310211
# Average loss at step  50000 :  1.4647483548223972
# Average loss at step  52000 :  1.4669909029304982
# Average loss at step  54000 :  1.4552360894978047
# Average loss at step  56000 :  1.4482024704515934
# Average loss at step  58000 :  1.4308443087637424
# Average loss at step  60000 :  1.4325970493853093
# Nearest to ['H2O;', 'Water']: ['7,9,12-Decaketide intermediate 6'], ['Prostaglandin H2;', '(5Z,13E)-(15S)-9alpha,11alpha-Epidioxy-15-hydroxyprosta-5,13-dienoate;', '(5Z,13E,15S)-9alpha,11alpha-Epidioxy-15-hydroxyprosta-5,13-dienoate;', 'PGH2;', '(5Z,9alpha,11alpha,13E,15S)-9,11-Epidioxy-15-hydroxy-prosta-5,13-dienoate'], ['3-Hydroxy-L-kynurenine'],
# Nearest to ['H+;', 'Hydron']: ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate'], ['3,5-Diiodo-4-hydroxyphenylpyruvate;', '3-(3,5-Diiodo-4-hydroxyphenyl)pyruvate'],
# Nearest to ['Oxygen;', 'O2']: ['[Reduced NADPH---hemoprotein reductase];', 'Reduced flavoprotein'], ['beta-Amyrin;', 'beta-Amyrenol'], ['I-Urobilinogen;', 'Mesobilirubinogen;', 'Urobilinogen'],
# Nearest to ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+']: ['Fusicocca-2,10(14)-diene'], ['(5Z)-(15S)-11alpha-Hydroxy-9,15-dioxoprostanoate'], ['Salutaridinol;', '5,6,8,14-Tetradehydro-3,6-dimethoxy-17-methyl-morphinan-4,7-diol'],
# Nearest to ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']: ['H+;', 'Hydron'], ['2-Naphthalenesulfonic acid;', 'Naphthalene-2-sulfonate'], ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'],
# Nearest to ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']: ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+'], ['beta-D-Glucosyl-1,4-N-acetyl-D-glucosaminyldiphosphoundecaprenol'], ['6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate'],
# Nearest to ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']: ['H+;', 'Hydron'], ['3-Dehydro-L-gulonate 6-phosphate'], ['Phenanthrene-3,4-diol;', '3,4-Dihydroxyphenanthrene'],
# Nearest to ['CO2;', 'Carbon dioxide']: ['Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-(L-alanyl-L-alanyl)-D-alanyl-D-alanine'], ['Succinate;', 'Succinic acid;', 'Butanedionic acid;', 'Ethylenesuccinic acid'], ['[Dihydrolipoyllysine-residue acetyltransferase] S-acetyldihydrolipoyllysine;', 'S-Acetyldihydrolipoamide-E;', 'Enzyme N6-(S-acetyldihydrolipoyl)lysine'],
# Nearest to ['ATP;', "Adenosine 5'-triphosphate"]: ["Dermatan 6'-sulfate"], ['1,6-Dihydroxy-5-methylcyclohexa-2,4-dienecarboxylate;', '1,2-Dihydroxy-3-methylcyclohexa-3,5-dienecarboxylate'], ['Azomycin;', '2-Nitroimidazole'],
# Nearest to ['Diphosphate;', 'Diphosphoric acid;', 'Pyrophosphate;', 'Pyrophosphoric acid;', 'PPi']: ['AMP;', "Adenosine 5'-monophosphate;", 'Adenylic acid;', 'Adenylate;', "5'-AMP;", "5'-Adenylic acid;", "5'-Adenosine monophosphate;", "Adenosine 5'-phosphate"], ['3-Chloro-L-alanine'], G13081,
# Average loss at step  62000 :  1.433040280044079
# Average loss at step  64000 :  1.421606932103634
# Average loss at step  66000 :  1.4320798530578613
# Average loss at step  68000 :  1.4106852990984917
# Average loss at step  70000 :  1.4101187068521976
# Average loss at step  72000 :  1.4088034161031247
# Average loss at step  74000 :  1.4052773391902447
# Average loss at step  76000 :  1.383523511081934
# Average loss at step  78000 :  1.389540131598711
# Average loss at step  80000 :  1.395331568211317
# Nearest to ['H2O;', 'Water']: ['Prostaglandin I2;', '(5Z,13E)-(15S)-6,9alpha-Epoxy-11alpha,15-dihydroxyprosta-5,13-dienoate;', 'Prostacyclin;', 'PGI2;', 'Epoprostenol'], ['3-Hydroxy-L-kynurenine'], ['Lychnose;', '1F-alpha-D-Galactosylraffinose'],
# Nearest to ['H+;', 'Hydron']: ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate'], ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['3,5-Diiodo-4-hydroxyphenylpyruvate;', '3-(3,5-Diiodo-4-hydroxyphenyl)pyruvate'],
# Nearest to ['Oxygen;', 'O2']: ['I-Urobilinogen;', 'Mesobilirubinogen;', 'Urobilinogen'], ['[Reduced NADPH---hemoprotein reductase];', 'Reduced flavoprotein'], ['beta-Amyrin;', 'beta-Amyrenol'],
# Nearest to ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+']: ['Fusicocca-2,10(14)-diene'], ['trans-1,2-Dichloroethene;', 'trans-Acetylene dichloride'], ['Salutaridinol;', '5,6,8,14-Tetradehydro-3,6-dimethoxy-17-methyl-morphinan-4,7-diol'],
# Nearest to ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']: ['H+;', 'Hydron'], ['Kdo2-lipid A 1-(2-aminoethyl diphosphate)'], ['trans-Hex-2-enoyl-[acp];', 'trans-Hex-2-enoyl-[acyl-carrier protein];', '(2E)-Hexenoyl-[acp]'],
# Nearest to ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']: ['Toluene-cis-dihydrodiol;', '(1S,2R)-3-Methylcyclohexa-3,5-diene-1,2-diol'], ['D-threo-Aldose;', '(2S,3R)-Aldose'], ['6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate'],
# Nearest to ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']: ['H+;', 'Hydron'], ['Phenanthrene-3,4-diol;', '3,4-Dihydroxyphenanthrene'], ['3-Dehydro-L-gulonate 6-phosphate'],
# Nearest to ['CO2;', 'Carbon dioxide']: ['Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-(L-alanyl-L-alanyl)-D-alanyl-D-alanine'], ['Succinate;', 'Succinic acid;', 'Butanedionic acid;', 'Ethylenesuccinic acid'], ['[Dihydrolipoyllysine-residue acetyltransferase] S-acetyldihydrolipoyllysine;', 'S-Acetyldihydrolipoamide-E;', 'Enzyme N6-(S-acetyldihydrolipoyl)lysine'],
# Nearest to ['ATP;', "Adenosine 5'-triphosphate"]: ["Dermatan 6'-sulfate"], ['13-(2-Methylcrotonoyl)oxylupanine;', '13-(2-Methylcrotonoyl)oxylupinine;', '(+)-13alpha-Tigloyloxylupanine'], ['1,3-beta-D-Galactosyl-N-acetyl-D-glucosaminyl-1,3-beta-D-galactosyl-1,4-D-glucosylceramide;', 'Ceramidetetrasaccharide;', 'Ceramidetetrahexoside;', 'Paragloboside;', 'Lc4Cer'],
# Nearest to ['Diphosphate;', 'Diphosphoric acid;', 'Pyrophosphate;', 'Pyrophosphoric acid;', 'PPi']: ['AMP;', "Adenosine 5'-monophosphate;", 'Adenylic acid;', 'Adenylate;', "5'-AMP;", "5'-Adenylic acid;", "5'-Adenosine monophosphate;", "Adenosine 5'-phosphate"], ['Isovitexin;', 'Saponaretin;', 'Apigenin-6-C-glucoside;', '6-C-Glucosylapigenin;', 'Apigenin 6-C-glucoside'], G13081,
# Average loss at step  82000 :  1.3803773542642594
# Average loss at step  84000 :  1.3876772345304489
# Average loss at step  86000 :  1.373542889326811
# Average loss at step  88000 :  1.3734037790894509
# Average loss at step  90000 :  1.376441251128912
# Average loss at step  92000 :  1.3657380270659925
# Average loss at step  94000 :  1.3778994340598583
# Average loss at step  96000 :  1.3791101959645748
# Average loss at step  98000 :  1.3804985006451607
# Average loss at step  100000 :  1.3636806494295597
# Nearest to ['H2O;', 'Water']: ['Salvianin'], ['1a,11b-Dihydro-4,9-dimethylbenz[a]anthra[3,4-b]oxirene'], ['Lychnose;', '1F-alpha-D-Galactosylraffinose'],
# Nearest to ['H+;', 'Hydron']: ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate'], ['3,5-Diiodo-4-hydroxyphenylpyruvate;', '3-(3,5-Diiodo-4-hydroxyphenyl)pyruvate'],
# Nearest to ['Oxygen;', 'O2']: ['I-Urobilinogen;', 'Mesobilirubinogen;', 'Urobilinogen'], ['[Reduced NADPH---hemoprotein reductase];', 'Reduced flavoprotein'], ['beta-Amyrin;', 'beta-Amyrenol'],
# Nearest to ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+']: ['trans-1,2-Dichloroethene;', 'trans-Acetylene dichloride'], ['Fusicocca-2,10(14)-diene'], ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+'],
# Nearest to ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']: ['H+;', 'Hydron'], ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide'], ['2-Naphthalenesulfonic acid;', 'Naphthalene-2-sulfonate'],
# Nearest to ['NAD+;', 'NAD;', 'Nicotinamide adenine dinucleotide;', 'DPN;', 'Diphosphopyridine nucleotide;', 'Nadide;', 'beta-NAD+']: ['NADP+;', 'NADP;', 'Nicotinamide adenine dinucleotide phosphate;', 'beta-Nicotinamide adenine dinucleotide phosphate;', 'TPN;', 'Triphosphopyridine nucleotide;', 'beta-NADP+'], ['6-Fluorocyclohexadiene-cis,cis-1,2-diol-1-carboxylate'], ['D-threo-Aldose;', '(2S,3R)-Aldose'],
# Nearest to ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']: ['H+;', 'Hydron'], ['Phenanthrene-3,4-diol;', '3,4-Dihydroxyphenanthrene'], ['3-Dehydro-L-gulonate 6-phosphate'],
# Nearest to ['CO2;', 'Carbon dioxide']: ['[Dihydrolipoyllysine-residue acetyltransferase] S-acetyldihydrolipoyllysine;', 'S-Acetyldihydrolipoamide-E;', 'Enzyme N6-(S-acetyldihydrolipoyl)lysine'], ['24-Methylenecholesterol'], ['Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-alanyl-gamma-D-glutamyl-L-lysyl-(L-alanyl-L-alanyl)-D-alanyl-D-alanine'],
# Nearest to ['ATP;', "Adenosine 5'-triphosphate"]: ["Dermatan 6'-sulfate"], ['13-(2-Methylcrotonoyl)oxylupanine;', '13-(2-Methylcrotonoyl)oxylupinine;', '(+)-13alpha-Tigloyloxylupanine'], ['alpha-2,8-Linked polymer of sialic acid;', 'Poly(sialoside)'],
# Nearest to ['Diphosphate;', 'Diphosphoric acid;', 'Pyrophosphate;', 'Pyrophosphoric acid;', 'PPi']: ['AMP;', "Adenosine 5'-monophosphate;", 'Adenylic acid;', 'Adenylate;', "5'-AMP;", "5'-Adenylic acid;", "5'-Adenosine monophosphate;", "Adenosine 5'-phosphate"], G13081, ['(2S,3S)-3-Hydroxyasparagine'],

# %% [markdown]
# ### Step 4: Analyze/Visualize the Data
# We can analyze the embeddings we have created by visualizing them in a low dimensional space and exploring which metabolites end up close to each other in the embeded space.

# %% [markdown]
# ##### Visualize the data using tSNE

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(
    perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in range(plot_only)]

# %%
import matplotlib.pyplot as plt
import numpy as np
import mpld3

x = low_dim_embs[:,0]
y = low_dim_embs[:,1]

fig, ax = plt.subplots(subplot_kw=dict(facecolor='#EEEEEE'))

scatter = ax.scatter(x,
                     y)
ax.grid(color='white', linestyle='solid')

tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
mpld3.plugins.connect(fig, tooltip)

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el649225643575468962956783423"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el649225643575468962956783423", {"width": 432.0, "height": 288.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-54.52376997616129, 58.65375197079019], "ylim": [-55.48500692270712, 57.146147364601646], "xdomain": [-54.52376997616129, 58.65375197079019], "ydomain": [-55.48500692270712, 57.146147364601646], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#FFFFFF", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#FFFFFF", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#EEEEEE", "axesbgalpha": null, "zoomable": true, "id": "el64922564101260848", "lines": [], "paths": [], "markers": [], "texts": [], "collections": [{"offsets": "data01", "xindex": 0, "yindex": 1, "paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "pathtransforms": [[6.0, 0.0, 0.0, 6.0, 0.0, 0.0]], "alphas": [null], "edgecolors": ["#1F77B4"], "facecolors": ["#1F77B4"], "edgewidths": [1.0], "offsetcoordinates": "data", "pathcoordinates": "display", "zorder": 1, "id": "el64922564368978720"}], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[-21.161285400390625, -6.164087772369385], [5.708032131195068, -1.9924025535583496], [-8.173439025878906, 44.698307037353516], [18.4571475982666, -1.0402203798294067], [19.37722396850586, -1.333935022354126], [-30.77799415588379, -5.031769275665283], [39.7140007019043, -0.4051695764064789], [-30.838613510131836, -14.528169631958008], [17.43463706970215, -12.607626914978027], [-38.68708419799805, 19.653722763061523], [-11.339595794677734, 23.390871047973633], [-39.5067253112793, 24.8717098236084], [25.917879104614258, 1.9248887300491333], [-22.534528732299805, -18.794639587402344], [-1.210322380065918, 13.160745620727539], [11.214293479919434, 33.677040100097656], [-38.64961624145508, 8.13825511932373], [12.115466117858887, 34.163978576660156], [-3.8189351558685303, 23.092317581176758], [-6.468896389007568, -29.70697021484375], [44.395660400390625, 0.542390763759613], [15.14933967590332, 27.158458709716797], [-15.858585357666016, 41.8052978515625], [-24.664278030395508, 28.55653190612793], [-12.486980438232422, 14.629435539245605], [-38.00917434692383, 25.14449119567871], [-10.273326873779297, 15.000499725341797], [13.939894676208496, -3.6111745834350586], [-3.5222952365875244, 37.67671203613281], [17.712060928344727, 16.53215980529785], [-28.516101837158203, -23.845476150512695], [22.91724967956543, 39.10020065307617], [-27.784841537475586, -10.461762428283691], [20.38713836669922, -21.630538940429688], [-45.90141296386719, 14.374853134155273], [-1.5963220596313477, 44.54952621459961], [8.160077095031738, -2.100281238555908], [20.95952033996582, -1.0344151258468628], [-14.539763450622559, -10.878851890563965], [-26.91071128845215, -33.08834457397461], [-24.797475814819336, -44.83458709716797], [2.2239177227020264, -25.56774139404297], [19.43514633178711, -16.04192543029785], [-9.163594245910645, 27.432426452 ...

# %% [markdown]
# ##### Analyze the data

# %%
# Explore Metabolite Similarity
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine

cos_sim = 1-pairwise_distances(final_embeddings, metric="cosine")

# %%
# What are the closest metabolites
topN = 50
cos_sim_1 = cos_sim - np.triu(cos_sim) # subtract upper triangel and diagonal
cos_sim_1d = cos_sim_1.flatten()
idx_1d = cos_sim_1d.argsort()[-topN:]
x_idx, y_idx = np.unravel_index(idx_1d, cos_sim.shape)

# %%
# cosine similarity vs number of times reactions co-occur
# count co-occurences
met_co = np.zeros_like(cos_sim)
for inds in data:
    for x in inds:
        for y in inds:
            met_co[x,y]=met_co[x,y]+1

# %%
# correlation of top n
from scipy.stats import spearmanr
rho, pval = spearmanr(met_co[x_idx,y_idx],cos_sim[x_idx,y_idx])
print(rho)
print(pval)
# Out:
# 0.35518043962829293
# 0.011370372299122942

# %%
plt.scatter(met_co[x_idx,y_idx],cos_sim[x_idx,y_idx])
plt.show()

# %%
# normalized co-occurence counts (only calculate for top n to save time)
met_co_norm = np.zeros_like(met_co)
for x,y in zip(x_idx, y_idx):
    met_co_norm[x,y] = 2*met_co[x,y]/(met_co[x,x]+met_co[y,y])

# %%
rho, pval = spearmanr(met_co_norm[x_idx,y_idx],cos_sim[x_idx,y_idx])
print(rho)
print(pval)
# Out:
# 0.3546270554065921
# 0.011507961824135436

# %%
plt.scatter(met_co_norm[x_idx,y_idx],cos_sim[x_idx,y_idx])
plt.show()

# %%
# print most similar metabolites along with metabolite co-occurence
for x,y in zip(x_idx, y_idx):
    if reverse_dictionary[x] in name_dictionary.keys():
        print(name_dictionary[reverse_dictionary[x]])
    else:
        print(reverse_dictionary[x])
    print([reverse_dictionary[x]])
    if reverse_dictionary[y] in name_dictionary.keys():
        print(name_dictionary[reverse_dictionary[y]])
    else:
        print(reverse_dictionary[y])
    print([reverse_dictionary[y]])
    print("Cosine Similarity: {}".format(cos_sim[x][y]))
    print("Metabolite Co-occurrence: {}".format(met_co[x][y]))
    print("Normalized Co-occurence: {}".format(met_co_norm[x][y]))
    print('')
# Out:
# ['Stipitatate;', 'Stipitatic acid;', '3,6-Dihydroxy-5-oxo-1,3,6-cycloheptatriene-1-carboxylic acid']
# ['C01853']
# ['2-(alpha-Hydroxypropyl)thiamine diphosphate;', '2-Hydroxypropyl-ThPP']
# ['C21017']
# Cosine Similarity: 0.5011411309242249
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Aklaviketone;', 'Methyl (1R,2R)-2-ethyl-2,5,7-trihydroxy-4,6,11-trioxo-1,2,3,4,6,11-hexahydrotetracene-1-carboxylate']
# ['C12423']
# ['N-Acyl-D-mannosaminolactone']
# ['C03792']
# Cosine Similarity: 0.5011688470840454
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Versiconal hemiacetal acetate']
# ['C20505']
# ['Cortisone;', '17alpha,21-Dihydroxy-4-pregnene-3,11,20-trione;', "Kendall's compound E;", "Reichstein's substance Fa"]
# ['C00762']
# Cosine Similarity: 0.5014297962188721
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Cinchonine;', '(9S)-Cinchonan-9-ol']
# ['C06528']
# ['Indan-1-ol']
# ['C01710']
# Cosine Similarity: 0.5014308094978333
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['1-Hydroxypyrene']
# ['C14519']
# ['Glutathione amide;', 'L-gamma-Glutamyl-L-cysteinylglycinamide']
# ['C19689']
# Cosine Similarity: 0.5016009211540222
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['N-Acetyl-alpha-D-galactosaminyl-diphospho-ditrans,octacis-undecaprenol;', 'N-Acetyl-alpha-D-galactosaminyl-1-diphospho-ditrans,octacis-undecaprenol']
# ['C20620']
# ['19(S)-HETE;', '(19S)-Hydroxyeicosatetraenoic acid;', '(19S)-Hydroxyicosatetraenoic acid;', '(19S)-Hydroxy arachidonic acid']
# ['C14749']
# Cosine Similarity: 0.5017939209938049
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# G00060
# ['G00060']
# ['(R)-3-(4-Hydroxyphenyl)lactate']
# ['C03964']
# Cosine Similarity: 0.5032463073730469
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['(-)-Sophorol']
# ['C16228']
# ['10-Deoxysarpagine;', 'Sarpagan-17-ol']
# ['C11635']
# Cosine Similarity: 0.5034247636795044
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Mycobilin b']
# ['C21625']
# ['Carboxyspermidine;', '2-Amino-4-[(4-aminobutyl)amino]-butanoic acid']
# ['C18172']
# Cosine Similarity: 0.5036523342132568
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['L-Hydroxylysine;', '5-Hydroxy-L-lysine;', 'L-erythro-5-Hydroxylysine;', '(5R)-5-Hydroxy-L-lysine']
# ['C16741']
# ['Chitobiose;', 'Diacetylchitobiose;', "N,N'-Diacetylchitobiose"]
# ['C01674']
# Cosine Similarity: 0.5037035942077637
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Pelargonidin 3-O-sophoroside']
# ['C16305']
# ['Benzo[a]pyrene-cis-11,12-dihydrodiol']
# ['C18284']
# Cosine Similarity: 0.5043787956237793
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['alpha-Aminoadipoyl-S-acyl enzyme;', 'Aminoadip.-S']
# ['C05535']
# ['3alpha,21-Dihydroxy-5beta-pregnane-11,20-dione;', '5beta-Pregnane-3alpha,21-diol-11,20-dione']
# ['C05478']
# Cosine Similarity: 0.5046436190605164
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['trans-4-Carboxymethylenebut-2-en-4-olide']
# ['C12838']
# ['N-Methylhistamine;', '1-Methylhistamine;', '1-Methyl-4-(2-aminoethyl)imidazole;', 'Ntau-Methylhistamine']
# ['C05127']
# Cosine Similarity: 0.5050257444381714
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Delta6-Protoilludene;', '(4aS,7aS,7bR)-3,6,6,7b-Tetramethyl-2,4,4a,5,6,7,7a,7b-octahydro-1H-cyclobuta[1,2-e]indene']
# ['C20476']
# ['(+)-endo-beta-Bergamotene']
# ['C19737']
# Cosine Similarity: 0.5054757595062256
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Ammelide;', '2,4-Dihydroxy-6-amino-1,3,5-triazine']
# ['C08734']
# ['Pelargonin;', 'Pelargonidin 3,5-di-beta-D-glucoside']
# ['C08725']
# Cosine Similarity: 0.5054880976676941
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['2-Descarboxy-betanidin']
# ['C17757']
# ['Nickel-sirohydrochlorin a,c-diamide;', 'Ni-sirohydrochlorin a,c-diamide']
# ['C21511']
# Cosine Similarity: 0.5064486265182495
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['2,4-Dichlorophenol']
# ['C02625']
# ['Morphinone']
# ['C01735']
# Cosine Similarity: 0.5064670443534851
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['4-Methylthiobutylthiohydroximate']
# ['C17243']
# ['Methylphosphonate']
# ['C20396']
# Cosine Similarity: 0.5065464377403259
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['cyclo-Dopa 5-O-glucoside']
# ['C17751']
# ['Cobalt-precorrin 5B']
# ['C16243']
# Cosine Similarity: 0.5068276524543762
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['e-;', 'Electron']
# ['C05359']
# ['2D-5-O-Methyl-2,3,5/4,6-pentahydroxycyclohexanone;', '5D-5-O-Methyl-2,3,5/4,6-pentahydroxycyclohexanone;', 'D-5-O-Methyl-2,3,5/4,6-pentahydroxycyclohexanone']
# ['C01295']
# Cosine Similarity: 0.5069931149482727
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['1,7-Dimethyluric acid']
# ['C16356']
# ['Indole-3-acetaldehyde;', '2-(Indol-3-yl)acetaldehyde;', 'Indoleacetaldehyde']
# ['C00637']
# Cosine Similarity: 0.5074390172958374
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['[Acetyl-CoA carboxylase]']
# ['C01139']
# ['Puromycin']
# ['C01610']
# Cosine Similarity: 0.5080211162567139
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['N-Acetyl-alpha-D-galactosamine 1-phosphate']
# ['C18060']
# ['Docosanoic acid;', 'Docosanoate;', 'Behenic acid']
# ['C08281']
# Cosine Similarity: 0.5080350041389465
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Pentanamide;', 'Valeramide']
# ['C01842']
# ['Androsta-1,4-diene-3,17-dione']
# ['C20144']
# Cosine Similarity: 0.508084237575531
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Chlorobenzene;', 'Monochlorobenzene;', 'Benzene chloride;', 'Phenyl chloride']
# ['C06990']
# ['H+;', 'Hydron']
# ['C00080']
# Cosine Similarity: 0.5082966089248657
# Metabolite Co-occurrence: 2.0
# Normalized Co-occurence: 0.0016142049571499228
#
# ['N2-Citryl-N6-acetyl-N6-hydroxy-L-lysine;', 'N2-Citryl-N6-acetyl-N6-hydroxylysine']
# ['C20333']
# ['(R)-2-Aza-beta-tyrosyl-[pcp]']
# ['C21327']
# Cosine Similarity: 0.5083333253860474
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['4-Phospho-D-erythronate;', '4-Phosphoerythronate']
# ['C03393']
# ['(R)-(+)-Citronellal']
# ['C09848']
# Cosine Similarity: 0.5095628499984741
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['12-Hydroxyjasmonoyl-L-amino acid']
# ['C21696']
# ['L-N-Hydroxypolyhomomethionine']
# ['C21536']
# Cosine Similarity: 0.5097706317901611
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['N-Acyl-aromatic-L-amino acid']
# ['C20735']
# ['2,3-Dihydroxybenzoate;', '2,3-Dihydroxybenzoic acid']
# ['C00196']
# Cosine Similarity: 0.5101321935653687
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['3,5-Diiodo-4-hydroxyphenylpyruvate;', '3-(3,5-Diiodo-4-hydroxyphenyl)pyruvate']
# ['C01244']
# ['H+;', 'Hydron']
# ['C00080']
# Cosine Similarity: 0.5109823942184448
# Metabolite Co-occurrence: 1.0
# Normalized Co-occurence: 0.0008071024785749614
#
# ['Coumermycin D']
# ['C12480']
# ['[Enzyme]-cysteine']
# ['C15811']
# Cosine Similarity: 0.5113548040390015
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Calicheamicin PsAg']
# ['C21340']
# ['7,8-Dihydrobiopterin;', 'L-erythro-7,8-Dihydrobiopterin']
# ['C02953']
# Cosine Similarity: 0.5130574107170105
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['N-Acetyl-D-glucosaminate']
# ['C01133']
# ['3-Sulfopyruvate;', '3-Sulfopyruvic acid']
# ['C05528']
# Cosine Similarity: 0.5149373412132263
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Urea-1-carboxylate;', 'Allophanate;', 'Allophanic acid']
# ['C01010']
# ['3-Phosphonopyruvate']
# ['C02798']
# Cosine Similarity: 0.5170915722846985
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['6,8-Dimethyl-6,7-didehydroergoline']
# ['C20409']
# ['3-Hexenal;', '(3Z)-Hexenal']
# ['C16310']
# Cosine Similarity: 0.5179684162139893
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# G00159
# ['G00159']
# G00037
# ['G00037']
# Cosine Similarity: 0.5194845795631409
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Stizolobinate;', 'Stizolobinic acid']
# ['C06048']
# ['Aminoacetaldehyde;', '2-Aminoacetaldehyde']
# ['C06735']
# Cosine Similarity: 0.5196869969367981
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Delphinidin 3-O-glucoside;', 'Mirtillin;', 'Delphinidin 3-glucoside;', 'Delphinidin 3-O-beta-D-glucoside']
# ['C12138']
# ['Pelargonidin 3-O-glucoside;', 'Pelargonidin 3-glucoside;', 'Pelargonidin 3-O-beta-D-glucoside']
# ['C12137']
# Cosine Similarity: 0.5210504531860352
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# G00058
# ['G00058']
# G00044
# ['G00044']
# Cosine Similarity: 0.5215345025062561
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Diacylglyceryl-N-trimethyl-2-aminoethylphosphonate;', 'Diacylglyceryl-2-trimethylaminoethylphosphonate;', 'Diacylglycerophosphonocholine']
# ['C05676']
# ['Tetrachlorohydroquinone;', '2,3,5,6-Tetrachlorohydroquinone']
# ['C03434']
# Cosine Similarity: 0.5239239931106567
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['(S)-Dihydroorotate;', '(S)-4,5-Dihydroorotate;', 'L-Dihydroorotate;', 'L-Dihydroorotic acid;', 'Dihydro-L-orotic acid']
# ['C00337']
# ['2-trans,6-trans-Farnesal;', 'trans,trans-Farnesal;', 'Farnesal;', '(2E,6E)-3,7,11-Trimethyl-2,6,10-dodecatrienal;', '(2E,6E)-Farnesal']
# ['C03461']
# Cosine Similarity: 0.5330972671508789
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Propanoyl-CoA;', 'Propionyl-CoA;', 'Propionyl coenzyme A']
# ['C00100']
# ['Butanoyl-CoA;', 'Butyryl-CoA']
# ['C00136']
# Cosine Similarity: 0.5349124073982239
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Anandamide;', 'Arachidonylethanolamide;', 'N-(5Z,8Z,11Z,14Z-Eicosatetraenoyl)-ethanolamine;', 'AEA']
# ['C11695']
# ['(S)-3-Hydroxytetradecanoyl-CoA']
# ['C05260']
# Cosine Similarity: 0.5351820588111877
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Antibiotic JI-20B;', 'JI-20B']
# ['C17705']
# ['Urate-3-ribonucleoside;', 'Uric acid ribonucleoside']
# ['C05513']
# Cosine Similarity: 0.5389536619186401
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['(Z)-2-Methylpropanal oxime']
# ['C20315']
# ['Selenite']
# ['C05684']
# Cosine Similarity: 0.5391837358474731
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['cis-2,3-Dihydro-2,3-dihydroxybiphenyl;', 'cis-3-Phenylcyclohexa-3,5-diene-1,2-diol;', '(1S,2R)-3-Phenylcyclohexa-3,5-diene-1,2-diol']
# ['C06589']
# ['1,2-Dihydroxy-8-methylnaphthalene']
# ['C14084']
# Cosine Similarity: 0.5475428700447083
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ['Cobalt-factor III']
# ['C17401']
# ['3-Mercaptolactate;', 'L-3-Mercaptolactate;', '(R)-3-Mercaptolactate']
# ['C05823']
# Cosine Similarity: 0.5760815739631653
# Metabolite Co-occurrence: 0.0
# Normalized Co-occurence: 0.0
#
# ["5'-Deoxyadenosine"]
# ['C05198']
# ['L-Methionine;', 'Methionine;', 'L-2-Amino-4methylthiobutyric acid']
# ['C00073']
# Cosine Similarity: 0.604776918888092
# Metabolite Co-occurrence: 35.0
# Normalized Co-occurence: 0.7291666865348816
#
# ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']
# ['C00005']
# ['H+;', 'Hydron']
# ['C00080']
# Cosine Similarity: 0.6077128648757935
# Metabolite Co-occurrence: 1145.0
# Normalized Co-occurence: 0.6236383318901062
#
# ['H+;', 'Hydron']
# ['C00080']
# ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']
# ['C00004']
# Cosine Similarity: 0.6828320622444153
# Metabolite Co-occurrence: 923.0
# Normalized Co-occurence: 0.5394505858421326

# %%
# Find closest metabolites to a particular metabolite
met = 'C00005'
topN = 10
cos_sim_met = cos_sim[dictionary[met]][:]
ids = cos_sim_met.argsort()[-topN:]

for x in ids:
    if reverse_dictionary[x] in name_dictionary.keys():
        print(name_dictionary[reverse_dictionary[x]])
    else:
        print(reverse_dictionary[x])
    print("Cosine Similarity: {}".format(cos_sim[x][dictionary[met]]))
    print("Metabolite Co-occurrence: {}".format(met_co[x][dictionary[met]]))
    print('')
# Out:
# ['Apocytochrome c']
# Cosine Similarity: 0.40415942668914795
# Metabolite Co-occurrence: 0.0
#
# ['Zeatin;', 'N6-(4-Hydroxyisopentenyl)adenine;', '(E)-2-Methyl-4-(1H-purin-6-ylamino)but-2-en-1-ol;', 'trans-Zeatin']
# Cosine Similarity: 0.4134293794631958
# Metabolite Co-occurrence: 1.0
#
# ['Kdo2-lipid A 1-(2-aminoethyl diphosphate)']
# Cosine Similarity: 0.4139225482940674
# Metabolite Co-occurrence: 0.0
#
# ['3-Iodo-L-tyrosine']
# Cosine Similarity: 0.41602468490600586
# Metabolite Co-occurrence: 1.0
#
# ['tert-Butyl alcohol;', 'tert-Butanol']
# Cosine Similarity: 0.4169883728027344
# Metabolite Co-occurrence: 1.0
#
# ['Cacodylate;', 'Dimethylarsinate']
# Cosine Similarity: 0.4214097261428833
# Metabolite Co-occurrence: 0.0
#
# ['2-Naphthalenesulfonic acid;', 'Naphthalene-2-sulfonate']
# Cosine Similarity: 0.42256826162338257
# Metabolite Co-occurrence: 0.0
#
# ['NADH;', 'DPNH;', 'Reduced nicotinamide adenine dinucleotide']
# Cosine Similarity: 0.4437883496284485
# Metabolite Co-occurrence: 0.0
#
# ['H+;', 'Hydron']
# Cosine Similarity: 0.6077128648757935
# Metabolite Co-occurrence: 1145.0
#
# ['NADPH;', 'TPNH;', 'Reduced nicotinamide adenine dinucleotide phosphate']
# Cosine Similarity: 1.0
# Metabolite Co-occurrence: 1196.0

# %% [markdown]
# ### Comments
# In this notebook we have implemented the skip-gram model from word2vec towards embedding metabolites by using metabolic reactions as the context. Metabolites that co-occur often with other metabolites such as the cofactors nadph and nadp or atp and adp have very high similarity in this embedding space. These metabolites can be thought of as "phrases" that co-occur often and thus are always found in similar context. Additionally, there are some metabolites that have high similarity in the embedding space, but low co-occurence. One example is, alpha-D-glucose, glc-D-B and glc-D. In the modelSEED database these metabolites are alpha-D-Glucose, beta-D-Glucose and D-Glucose, respectively. These metabolites have similar structure and participate in similar reacitons. For example, in the modelSEED database rxn00007 hydrolyzes Trehalose to 2 D-Glucose, while rxn15002 hydrolyzes Trehalose to 2 alpha-D-Glucose.
#
# #### Future Directions:
# * Embed metabolite "phrases" by reassigning highly co-occurring metabolites to a unique "phrase" IDs
# * Utilize more sophisticated reaction structures such as KEGG reaction classes to embed different components of reactions
